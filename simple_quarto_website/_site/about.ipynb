# %% [markdown]
# ---
# title: "About"
# format: html
# ---

# %% [markdown]
# About this site

# %% [markdown]
# # PART 1
# Laoreet suspendisse interdum consectetur libero. Fermentum dui faucibus in ornare quam viverra orci sagittis eu. Feugiat nibh sed pulvinar proin. Ullamcorper morbi tincidunt ornare massa eget egestas purus viverra accumsan. Mi tempus imperdiet nulla malesuada. Gravida cum sociis natoque penatibus. Id volutpat lacus laoreet non curabitur.

# %% [markdown]
# ## PART 1.1
# Adipiscing elit ut aliquam purus sit. Cras adipiscing enim eu turpis egestas pretium aenean. Nam libero justo laoreet sit amet cursus sit amet. Quis blandit turpis cursus in hac habitasse platea dictumst quisque. Donec enim diam vulputate ut pharetra sit amet aliquam. Dolor sit amet consectetur adipiscing elit duis tristique sollicitudin nibh. Ac odio tempor orci dapibus ultrices in iaculis nunc. Sagittis orci a scelerisque purus semper eget. Bibendum arcu vitae elementum curabitur vitae nunc.

# %%
import matplotlib.pyplot as plt
import numpy as np
# Create a Figure with 2 rows and 2 columns of subplots:
fig, ax = plt.subplots(2, 2)
x = np.linspace(0, 5, 100)
# Index 4 Axes arrays in 4 subplots within 1 Figure: 
ax[0, 0].plot(x, np.sin(x), 'g') #row=0, column=0
ax[1, 0].plot(range(100), 'b') #row=1, column=0
ax[0, 1].plot(x, np.cos(x), 'r') #row=0, column=1
ax[1, 1].plot(x, np.tan(x), 'k') #row=1, column=1
plt.show()

# %% [markdown]
# ### PART 1.1.1
# Sed felis eget velit aliquet sagittis id consectetur. Amet justo donec enim diam. Vel risus commodo viverra maecenas. Pulvinar elementum integer enim neque volutpat ac tincidunt vitae semper. Libero justo laoreet sit amet cursus. Aliquam eleifend mi in nulla. Suspendisse sed nisi lacus sed viverra tellus in hac habitasse. Arcu odio ut sem nulla pharetra diam sit amet. Lacus sed viverra tellus in hac habitasse. Dolor morbi non arcu risus quis varius quam quisque id. Viverra suspendisse potenti nullam ac tortor vitae purus faucibus.
